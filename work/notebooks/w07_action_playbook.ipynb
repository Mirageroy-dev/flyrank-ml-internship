# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mirageroy-dev/flyrank-ml-internship/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*

# %%
Path("../outputs").mkdir(exist_ok=True)
Path("../figures").mkdir(exist_ok=True)

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*

# %%
try:
    df = pd.read_csv("../data/processed_data.csv")
except:
    print("Processed data file not found. Using sample action data.")

    df = pd.DataFrame({
        "feature": [
            "Content Quality",
            "Keyword Relevance",
            "Page Load Speed",
            "Backlinks",
            "Content Freshness"
        ],
        "importance": [0.30, 0.25, 0.20, 0.15, 0.10],
        "current_score": [65, 70, 55, 60, 50]
    })

df.head()
# Out:
# Processed data file not found. Using sample action data.
#              feature  importance  current_score
# 0    Content Quality        0.30             65
# 1  Keyword Relevance        0.25             70
# 2    Page Load Speed        0.20             55
# 3          Backlinks        0.15             60
# 4  Content Freshness        0.10             50

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*

# %%
actions = pd.DataFrame({
    "Rank": [1, 2, 3, 4, 5],
    "Action": [
        "Improve low-performing content",
        "Improve keyword relevance",
        "Optimize page speed",
        "Strengthen backlink strategy",
        "Refresh outdated content"
    ],
    "Reason_Code": [
        "CONTENT_GAP",
        "KEYWORD_GAP",
        "PERFORMANCE_ISSUE",
        "AUTHORITY_GAP",
        "CONTENT_DECAY"
    ],
    "Priority": [
        "High",
        "High",
        "Medium",
        "Medium",
        "Medium"
    ]
})

actions
# Out:
#    Rank                          Action        Reason_Code Priority
# 0     1  Improve low-performing content        CONTENT_GAP     High
# 1     2       Improve keyword relevance        KEYWORD_GAP     High
# 2     3             Optimize page speed  PERFORMANCE_ISSUE   Medium
# 3     4    Strengthen backlink strategy      AUTHORITY_GAP   Medium
# 4     5        Refresh outdated content      CONTENT_DECAY   Medium

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*

# %%
archetype_mapping = pd.DataFrame({
    "Archetype": [
        "Low content performance",
        "Low keyword relevance",
        "Slow website performance",
        "Low website authority",
        "Outdated content"
    ],
    "Recommended_Action": [
        "Rewrite and improve weak content",
        "Improve keyword targeting and search intent alignment",
        "Optimize images, scripts, and page loading",
        "Build relevant and high-quality backlinks",
        "Update old information and refresh content"
    ]
})

archetype_mapping
# Out:
#                   Archetype                                 Recommended_Action
# 0   Low content performance                   Rewrite and improve weak content
# 1     Low keyword relevance  Improve keyword targeting and search intent al...
# 2  Slow website performance         Optimize images, scripts, and page loading
# 3     Low website authority          Build relevant and high-quality backlinks
# 4          Outdated content         Update old information and refresh content

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
